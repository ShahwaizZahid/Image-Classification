# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv2.imread('./test_images/sharapova1.jpg')
img.shape
(555, 700, 3)

plt.imshow(img)
